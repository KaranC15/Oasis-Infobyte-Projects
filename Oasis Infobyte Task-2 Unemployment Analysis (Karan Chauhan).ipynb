# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from datetime import datetime

# %%
df = pd.read_csv('Unemployment in India.csv')
df
# Out:
#              Region         Date  Frequency   Estimated Unemployment Rate (%)  \
# 0    Andhra Pradesh   31-05-2019    Monthly                              3.65
# 1    Andhra Pradesh   30-06-2019    Monthly                              3.05
# 2    Andhra Pradesh   31-07-2019    Monthly                              3.75
# 3    Andhra Pradesh   31-08-2019    Monthly                              3.32
# 4    Andhra Pradesh   30-09-2019    Monthly                              5.17
# ..              ...          ...        ...                               ...
# 763             NaN          NaN        NaN                               NaN
# 764             NaN          NaN        NaN                               NaN
# 765             NaN          NaN        NaN                               NaN
# 766             NaN          NaN        NaN                               NaN
# 767             NaN          NaN        NaN                               NaN
#
# ...

# %%
df.isna().sum()
# Out:
# Region                                      28
#  Date                                       28
#  Frequency                                  28
#  Estimated Unemployment Rate (%)            28
#  Estimated Employed                         28
#  Estimated Labour Participation Rate (%)    28
# Area                                        28
# dtype: int64

# %%
df = df.dropna()
df
# Out:
#              Region         Date  Frequency   Estimated Unemployment Rate (%)  \
# 0    Andhra Pradesh   31-05-2019    Monthly                              3.65
# 1    Andhra Pradesh   30-06-2019    Monthly                              3.05
# 2    Andhra Pradesh   31-07-2019    Monthly                              3.75
# 3    Andhra Pradesh   31-08-2019    Monthly                              3.32
# 4    Andhra Pradesh   30-09-2019    Monthly                              5.17
# ..              ...          ...        ...                               ...
# 749     West Bengal   29-02-2020    Monthly                              7.55
# 750     West Bengal   31-03-2020    Monthly                              6.67
# 751     West Bengal   30-04-2020    Monthly                             15.63
# 752     West Bengal   31-05-2020    Monthly                             15.22
# 753     West Bengal   30-06-2020    Monthly                              9.86
#
# ...

# %%
df.isna().sum()
# Out:
# Region                                      0
#  Date                                       0
#  Frequency                                  0
#  Estimated Unemployment Rate (%)            0
#  Estimated Employed                         0
#  Estimated Labour Participation Rate (%)    0
# Area                                        0
# dtype: int64

# %%
df.Region.unique()
# Out:
# array(['Andhra Pradesh', 'Assam', 'Bihar', 'Chhattisgarh', 'Delhi', 'Goa',
#        'Gujarat', 'Haryana', 'Himachal Pradesh', 'Jammu & Kashmir',
#        'Jharkhand', 'Karnataka', 'Kerala', 'Madhya Pradesh',
#        'Maharashtra', 'Meghalaya', 'Odisha', 'Puducherry', 'Punjab',
#        'Rajasthan', 'Sikkim', 'Tamil Nadu', 'Telangana', 'Tripura',
#        'Uttar Pradesh', 'Uttarakhand', 'West Bengal', 'Chandigarh'],
#       dtype=object)

# %%
df.Region.value_counts()
# Out:
# Andhra Pradesh      28
# Kerala              28
# West Bengal         28
# Uttar Pradesh       28
# Tripura             28
# Telangana           28
# Tamil Nadu          28
# Rajasthan           28
# Punjab              28
# Odisha              28
# Madhya Pradesh      28
# Maharashtra         28
# Karnataka           28
# Jharkhand           28
# Himachal Pradesh    28
# Haryana             28
# Gujarat             28
# Delhi               28
# Chhattisgarh        28
# Bihar               28
# Meghalaya           27
# Uttarakhand         27
# Assam               26
# Puducherry          26
# Goa                 24
# Jammu & Kashmir     21
# Sikkim              17
# Chandigarh          12
# Name: Region, dtype: int64

# %%
plt.figure(figsize = (12,10))
sns.countplot(y = df.Region)
plt.xlim(8)
plt.title('No. Of Time States Are Repeated In Dataframe')
plt.show()

# %%
df[' Frequency'].value_counts()
# Out:
# Monthly     381
#  Monthly    359
# Name:  Frequency, dtype: int64

# %%
df[' Date'].value_counts()
# Out:
#  31-10-2019    55
#  30-11-2019    55
#  31-05-2019    54
#  30-06-2019    54
#  31-07-2019    54
#  31-08-2019    53
#  31-12-2019    53
#  31-01-2020    53
#  29-02-2020    53
#  30-09-2019    52
#  31-03-2020    52
#  30-04-2020    51
#  31-05-2020    51
#  30-06-2020    50
# Name:  Date, dtype: int64

# %%
sns.pairplot(df,hue = ' Estimated Unemployment Rate (%)')

# %%
sns.histplot(x=" Estimated Employed", hue="Region", data=df)
plt.title("Indian Unemployment")
plt.show()

# %%
sns.heatmap(df.corr())
# Out:
# <AxesSubplot:>

# %%
sns.countplot(df['Area'])
# Out:
# C:\Users\Karan Chauhan\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Area', ylabel='count'>

# %%
df
# Out:
#              Region         Date  Frequency   Estimated Unemployment Rate (%)  \
# 0    Andhra Pradesh   31-05-2019    Monthly                              3.65
# 1    Andhra Pradesh   30-06-2019    Monthly                              3.05
# 2    Andhra Pradesh   31-07-2019    Monthly                              3.75
# 3    Andhra Pradesh   31-08-2019    Monthly                              3.32
# 4    Andhra Pradesh   30-09-2019    Monthly                              5.17
# ..              ...          ...        ...                               ...
# 749     West Bengal   29-02-2020    Monthly                              7.55
# 750     West Bengal   31-03-2020    Monthly                              6.67
# 751     West Bengal   30-04-2020    Monthly                             15.63
# 752     West Bengal   31-05-2020    Monthly                             15.22
# 753     West Bengal   30-06-2020    Monthly                              9.86
#
# ...

# %%
df[' Date'] = pd.to_datetime(df[' Date'])
df
# Out:
# C:\Users\KARANC~1\AppData\Local\Temp/ipykernel_62980/228097917.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[' Date'] = pd.to_datetime(df[' Date'])
#              Region       Date  Frequency   Estimated Unemployment Rate (%)  \
# 0    Andhra Pradesh 2019-05-31    Monthly                              3.65
# 1    Andhra Pradesh 2019-06-30    Monthly                              3.05
# 2    Andhra Pradesh 2019-07-31    Monthly                              3.75
# 3    Andhra Pradesh 2019-08-31    Monthly                              3.32
# 4    Andhra Pradesh 2019-09-30    Monthly                              5.17
# ..              ...        ...        ...                               ...
# ...

# %%
plt.figure(figsize = (16,12))
df.groupby(['Region', 'Area'])[' Estimated Unemployment Rate (%)'].mean().plot(kind='barh', stacked=True, color=['red', 'green'])
# Out:
# <AxesSubplot:ylabel='Region,Area'>

# %%
northern_states=['Delhi','Haryana', 'Bihar', 'Gujarat']

# %%
# Out:
# Text(0.5, 1.0, 'Monthly Temperatures in a year')

# %%
dfff
# Out:
#      High Temp  Low Temp  Avg Temp
# Jan         28        22        25
# Feb         30        26        28
# Mar         34        30        32
# Apr         38        32        35
# May         45        41        43
# Jun         42        38        40
# Jul         38        32        35
# Aug         35        31        33
# Sep         32        28        30
# Oct         28        22        25
# Nov         25        15        20
# Dec         21        15        18

# %%
x = (df.groupby(['Region', 'Area'])[' Estimated Unemployment Rate (%)'].mean().agg(list))
x.insert(6,0.000000)
len(x[::2])
len(x[1::2])
len(x)
# Out:
# 56

# %%
pd.DataFrame({'Rural':[5.526429,4.490833,16.770000,15.991667,15.258571,8.390000,5.917143,25.012857,15.504286,14.951818,15.221429,7.224286,10.341429,5.653571,6.810000,2.475000,6.612857,7.263333,11.925000,10.927143,5.080000,8.775714,7.863571,27.166429,10.208571,4.882308,7.572143]})
# Out:
#         Rural
# 0    5.526429
# 1    4.490833
# 2   16.770000
# 3   15.991667
# 4   15.258571
# 5    8.390000
# 6    5.917143
# 7   25.012857
# 8   15.504286
# 9   14.951818
# 10  15.221429
# 11   7.224286
# 12  10.341429
# 13   5.653571
# 14   6.810000
# 15   2.475000
# 16   6.612857
# 17   7.263333
# 18  11.925000
# 19  10.927143
# 20   5.080000
# 21   8.775714
# 22   7.863571
# 23  27.166429
# 24  10.208571
# 25   4.882308
# 26   7.572143

# %%
li = [1,2,3,4,5]
li.insert(3,0)
li
# Out:
# [1, 2, 3, 0, 4, 5]

# %%
reg = list(df.Region.unique())

# %%
# pd.DataFrame({'Rural':x[::2], 'Urban':x[1::2]})

# %%
y
# Out:
# Region            Area
# Andhra Pradesh    Rural     5.526429
#                   Urban     9.427857
# Assam             Rural     4.490833
#                   Urban     8.088571
# Bihar             Rural    16.770000
#                   Urban    21.066429
# Chandigarh        Urban    15.991667
# Chhattisgarh      Rural     6.628571
#                   Urban    11.852143
# Delhi             Rural    15.258571
#                   Urban    17.732143
# Goa               Rural     8.390000
#                   Urban    10.158333
# Gujarat           Rural     5.917143
#                   Urban     7.410714
# Haryana           Rural    25.012857
#                   Urban    27.553571
# Himachal Pradesh  Rural    15.504286
#                   Urban    21.576429
# Jammu & Kashmir   Rural    14.951818
#                   Urban    17.549000
# Jharkhand         Rural    15.221429
#                   Urban    25.948571
# Karnataka         Rural     7.224286
#                   Urban     6.127857
# ...

# %%
reg = reg[:-1]
reg.insert(3,'Chandigarh')
len(reg)
# Out:
# 28

# %%
reg
# Out:
# ['Andhra Pradesh',
#  'Assam',
#  'Bihar',
#  'Chandigarh',
#  'Chhattisgarh',
#  'Delhi',
#  'Goa',
#  'Gujarat',
#  'Haryana',
#  'Himachal Pradesh',
#  'Jammu & Kashmir',
#  'Jharkhand',
#  'Karnataka',
#  'Kerala',
#  'Madhya Pradesh',
#  'Maharashtra',
#  'Meghalaya',
#  'Odisha',
#  'Puducherry',
#  'Punjab',
#  'Rajasthan',
#  'Sikkim',
#  'Tamil Nadu',
#  'Telangana',
#  'Tripura',
#  'Uttar Pradesh',
#  'Uttarakhand',
#  'West Bengal']

# %%
tp = pd.DataFrame({'Region':reg,'Rural':x[::2],'Urban':x[1::2]})
tp
# Out:
#               Region      Rural      Urban
# 0     Andhra Pradesh   5.526429   9.427857
# 1              Assam   4.490833   8.088571
# 2              Bihar  16.770000  21.066429
# 3         Chandigarh   0.000000  15.991667
# 4       Chhattisgarh   6.628571  11.852143
# 5              Delhi  15.258571  17.732143
# 6                Goa   8.390000  10.158333
# 7            Gujarat   5.917143   7.410714
# 8            Haryana  25.012857  27.553571
# 9   Himachal Pradesh  15.504286  21.576429
# 10   Jammu & Kashmir  14.951818  17.549000
# 11         Jharkhand  15.221429  25.948571
# 12         Karnataka   7.224286   6.127857
# 13            Kerala  10.341429   9.906429
# 14    Madhya Pradesh   5.653571   9.159286
# 15       Maharashtra   6.810000   8.305000
# 16         Meghalaya   2.475000   7.301538
# 17            Odisha   6.612857   4.702857
# 18        Puducherry   7.263333  12.745000
# 19            Punjab  11.925000  12.137143
# 20         Rajasthan  10.927143  17.189286
# ...

# %%
tp = tp.set_index('Region')

# %%
tp.plot(kind='barh',stacked=True, figsize=(15,12))
plt.title('Average Estimated Unemployment Rate (%)')
plt.show()

# %%
df
# Out:
#              Region       Date  Frequency   Estimated Unemployment Rate (%)  \
# 0    Andhra Pradesh 2019-05-31    Monthly                              3.65
# 1    Andhra Pradesh 2019-06-30    Monthly                              3.05
# 2    Andhra Pradesh 2019-07-31    Monthly                              3.75
# 3    Andhra Pradesh 2019-08-31    Monthly                              3.32
# 4    Andhra Pradesh 2019-09-30    Monthly                              5.17
# ..              ...        ...        ...                               ...
# 749     West Bengal 2020-02-29    Monthly                              7.55
# 750     West Bengal 2020-03-31    Monthly                              6.67
# 751     West Bengal 2020-04-30    Monthly                             15.63
# 752     West Bengal 2020-05-31    Monthly                             15.22
# 753     West Bengal 2020-06-30    Monthly                              9.86
#
# ...

# %%
df.groupby('Region')[' Estimated Employed'].sum().plot(kind='barh', figsize=(12,10),color='tan')
plt.title('Estimated Employed In Each State')
plt.show()

# %%
(df.groupby(['Region', 'Area'])[' Estimated Labour Participation Rate (%)'].mean())
# Out:
# Region            Area
# Andhra Pradesh    Rural    42.963571
#                   Urban    35.787857
# Assam             Rural    47.072500
#                   Urban    42.979286
# Bihar             Rural    38.417143
#                   Urban    37.890714
# Chandigarh        Urban    39.336667
# Chhattisgarh      Rural    42.442857
#                   Urban    43.178571
# Delhi             Rural    36.993571
#                   Urban    40.865714
# Goa               Rural    38.853333
#                   Urban    39.645833
# Gujarat           Rural    50.334286
#                   Urban    41.867857
# Haryana           Rural    45.220714
#                   Urban    40.253571
# Himachal Pradesh  Rural    41.827857
#                   Urban    46.616429
# Jammu & Kashmir   Rural    40.137273
#                   Urban    42.014000
# Jharkhand         Rural    40.329286
#                   Urban    43.012143
# Karnataka         Rural    42.725714
#                   Urban    39.965000
# ...

# %%
x2 = (df.groupby(['Region', 'Area'])[' Estimated Labour Participation Rate (%)'].mean().agg(list))
x2.insert(6,0.000000)
len(x2[::2])
len(x2[1::2])
# (x2)
# Out:
# 28

# %%
tp2 = pd.DataFrame({'Region':reg, 'Ruaral':x2[::2],'Urban':x2[1::2]})
tp2 = tp2.set_index('Region')
tp2
# Out:
#                      Ruaral      Urban
# Region
# Andhra Pradesh    42.963571  35.787857
# Assam             47.072500  42.979286
# Bihar             38.417143  37.890714
# Chandigarh         0.000000  39.336667
# Chhattisgarh      42.442857  43.178571
# Delhi             36.993571  40.865714
# Goa               38.853333  39.645833
# Gujarat           50.334286  41.867857
# Haryana           45.220714  40.253571
# Himachal Pradesh  41.827857  46.616429
# Jammu & Kashmir   40.137273  42.014000
# Jharkhand         40.329286  43.012143
# Karnataka         42.725714  39.965000
# Kerala            35.487143  34.248571
# Madhya Pradesh    39.815000  37.827857
# Maharashtra       47.387143  37.219286
# Meghalaya         63.451429  50.220000
# Odisha            39.384286  38.468571
# Puducherry        42.521667  35.967857
# Punjab            43.911429  38.365000
# Rajasthan         40.594286  39.352143
# Sikkim            44.696000  46.642500
# Tamil Nadu        45.732143  36.012143
# ...

# %%
tp2.plot(kind='barh',stacked = True, figsize= (12,10), color=['red','green'])
plt.title('Average Estimated Labour Participation Rate (%)')
plt.show()

# %%
dff = df.copy()
dff
# Out:
#              Region       Date  Frequency   Estimated Unemployment Rate (%)  \
# 0    Andhra Pradesh 2019-05-31    Monthly                              3.65
# 1    Andhra Pradesh 2019-06-30    Monthly                              3.05
# 2    Andhra Pradesh 2019-07-31    Monthly                              3.75
# 3    Andhra Pradesh 2019-08-31    Monthly                              3.32
# 4    Andhra Pradesh 2019-09-30    Monthly                              5.17
# ..              ...        ...        ...                               ...
# 749     West Bengal 2020-02-29    Monthly                              7.55
# 750     West Bengal 2020-03-31    Monthly                              6.67
# 751     West Bengal 2020-04-30    Monthly                             15.63
# 752     West Bengal 2020-05-31    Monthly                             15.22
# 753     West Bengal 2020-06-30    Monthly                              9.86
#
# ...

# %%
# dff['Year'] = dff[' Date'].dt.year
dff['Month'] = dff[' Date'].dt.month
dff['Date'] = dff[' Date'].dt.day
dff
# Out:
#              Region       Date  Frequency   Estimated Unemployment Rate (%)  \
# 0    Andhra Pradesh 2019-05-31    Monthly                              3.65
# 1    Andhra Pradesh 2019-06-30    Monthly                              3.05
# 2    Andhra Pradesh 2019-07-31    Monthly                              3.75
# 3    Andhra Pradesh 2019-08-31    Monthly                              3.32
# 4    Andhra Pradesh 2019-09-30    Monthly                              5.17
# ..              ...        ...        ...                               ...
# 749     West Bengal 2020-02-29    Monthly                              7.55
# 750     West Bengal 2020-03-31    Monthly                              6.67
# 751     West Bengal 2020-04-30    Monthly                             15.63
# 752     West Bengal 2020-05-31    Monthly                             15.22
# 753     West Bengal 2020-06-30    Monthly                              9.86
#
# ...

# %%
dff.groupby(['Region','Year'])[' Estimated Unemployment Rate (%)'].mean()[1::2].plot(kind = 'barh', figsize = (12,10),color = 'olive')
# Out:
# <AxesSubplot:ylabel='Region,Year'>

# %%
x3 = (dff.groupby(['Region', 'Year'])[' Estimated Labour Participation Rate (%)'].mean().agg(list))
x3.insert(6,0.000000)
len(x3[::2])
len(x3[1::2])
# (x3)
# dff.groupby(['Region', 'Year'])[' Estimated Labour Participation Rate (%)'].mean()
# Out:
# 28

# %%
tp3 = pd.DataFrame({'Region':reg, '2019':x3[::2],'2020':x3[1::2]})
tp3 = tp3.set_index('Region')
tp3
# Out:
#                        2019       2020
# Region
# Andhra Pradesh    42.963571  35.787857
# Assam             47.072500  42.979286
# Bihar             38.417143  37.890714
# Chandigarh         0.000000  39.336667
# Chhattisgarh      42.442857  43.178571
# Delhi             36.993571  40.865714
# Goa               38.853333  39.645833
# Gujarat           50.334286  41.867857
# Haryana           45.220714  40.253571
# Himachal Pradesh  41.827857  46.616429
# Jammu & Kashmir   40.137273  42.014000
# Jharkhand         40.329286  43.012143
# Karnataka         42.725714  39.965000
# Kerala            35.487143  34.248571
# Madhya Pradesh    39.815000  37.827857
# Maharashtra       47.387143  37.219286
# Meghalaya         63.451429  50.220000
# Odisha            39.384286  38.468571
# Puducherry        42.521667  35.967857
# Punjab            43.911429  38.365000
# Rajasthan         40.594286  39.352143
# Sikkim            44.696000  46.642500
# Tamil Nadu        45.732143  36.012143
# ...

# %%
tp3.plot(kind='barh', figsize = (15,12), color = ['blue', 'lime'])
plt.xlim(30)
plt.title('Average Estimated Labour Participation Rate (%) in year 2019 and 2020')
plt.show()
